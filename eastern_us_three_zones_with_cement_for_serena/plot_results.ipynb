# %%
using Plots
using StatsPlots
using CSV
using DataFrames
using DataStructures

# %%
import Pkg; Pkg.add("DataStructures")
# Out:
#    Resolving package versions...
#       Compat entries added for DataStructures
#     Updating `~/Documents/MacroEnergy.jl/Project.toml`
#   [864edb3b] + DataStructures v0.18.22
#   No Changes to `~/Documents/MacroEnergy.jl/Manifest.toml`

# %%
import Pkg; Pkg.add("StatsPlots")
# Out:
#    Resolving package versions...
#    Installed Distances ─────────────── v0.10.12
#    Installed IntelOpenMP_jll ───────── v2025.0.4+0
#    Installed PDMats ────────────────── v0.11.35
#    Installed FFTW ──────────────────── v1.9.0
#    Installed OffsetArrays ──────────── v1.17.0
#    Installed StatsFuns ─────────────── v1.5.0
#    Installed HypergeometricFunctions ─ v0.3.28
#    Installed NearestNeighbors ──────── v0.4.21
#    Installed AbstractFFTs ──────────── v1.5.0
#    Installed ChainRulesCore ────────── v1.25.1
#    Installed MKL_jll ───────────────── v2025.0.1+1
#    Installed Clustering ────────────── v0.15.8
#    Installed Rmath_jll ─────────────── v0.5.1+0
#    Installed FFTW_jll ──────────────── v3.3.11+0
#    Installed Interpolations ────────── v0.15.1
#    Installed oneTBB_jll ────────────── v2022.0.0+0
#    Installed MultivariateStats ─────── v0.10.3
#    Installed Widgets ───────────────── v0.6.7
#    Installed StatsPlots ────────────── v0.15.7
#    Installed Ratios ────────────────── v0.4.5
#    Installed Adapt ─────────────────── v4.3.0
#    Installed Arpack_jll ────────────── v3.5.1+1
#    Installed KernelDensity ─────────── v0.6.9
#    Installed AxisAlgorithms ────────── v1.1.0
#    Installed QuadGK ────────────────── v2.11.2
#    Installed Observables ───────────── v0.5.5
#    Installed WoodburyMatrices ──────── v1.0.0
#    Installed Arpack ────────────────── v0.5.4
#    Installed Rmath ─────────────────── v0.8.0
#    Installed Distributions ─────────── v0.25.120
#       Compat entries added for StatsPlots
#     Updating `~/Documents/MacroEnergy.jl/Project.toml`
#   [f3b207a7] + StatsPlots v0.15.7
#     Updating `~/Documents/MacroEnergy.jl/Manifest.toml`
#   [621f4979] + AbstractFFTs v1.5.0
#   [79e6a3ab] + Adapt v4.3.0
#   [7d9fca2a] + Arpack v0.5.4
#   [13072b0f] + AxisAlgorithms v1.1.0
#   [d360d2e6] + ChainRulesCore v1.25.1
#   [aaaa29a8] + Clustering v0.15.8
#   [b4f34e82] + Distances v0.10.12
#   [31c24e10] + Distributions v0.25.120
#   [7a1cc6ca] + FFTW v1.9.0
#   [34004b35] + HypergeometricFunctions v0.3.28
# ⌅ [a98d9a8b] + Interpolations v0.15.1
#   [5ab0869b] + KernelDensity v0.6.9
#   [6f286f6a] + MultivariateStats v0.10.3
#   [b8a86587] + NearestNeighbors v0.4.21
#   [510215fc] + Observables v0.5.5
#   [6fe1bfb0] + OffsetArrays v1.17.0
#   [90014a1f] + PDMats v0.11.35
#   [1fd47b50] + QuadGK v2.11.2
#   [c84ed2f1] + Ratios v0.4.5
#   [79098fc4] + Rmath v0.8.0
#   [4c63d2b9] + StatsFuns v1.5.0
#   [f3b207a7] + StatsPlots v0.15.7
#   [cc8bc4a8] + Widgets v0.6.7
#   [efce3f68] + WoodburyMatrices v1.0.0
# ⌅ [68821587] + Arpack_jll v3.5.1+1
#   [f5851436] + FFTW_jll v3.3.11+0
#   [1d5cc7b8] + IntelOpenMP_jll v2025.0.4+0
#   [856f044c] + MKL_jll v2025.0.1+1
#   [f50d1b31] + Rmath_jll v0.5.1+0
#   [1317d2d5] + oneTBB_jll v2022.0.0+0
#   [4af54fe1] + LazyArtifacts v1.11.0
#   [1a1011a3] + SharedArrays v1.11.0
#   [4607b0f0] + SuiteSparse
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#     400.1 ms  ✓ Ratios
#     445.7 ms  ✓ Rmath_jll
#     489.2 ms  ✓ AbstractFFTs
#     406.6 ms  ✓ Observables
#     402.4 ms  ✓ Adapt
#     442.7 ms  ✓ oneTBB_jll
#     483.8 ms  ✓ WoodburyMatrices
#     519.8 ms  ✓ Distances
#     559.9 ms  ✓ PDMats
#     623.0 ms  ✓ OffsetArrays
#     323.3 ms  ✓ FFTW_jll
#     341.9 ms  ✓ Arpack_jll
#     781.3 ms  ✓ ChainRulesCore
#     444.4 ms  ✓ Ratios → RatiosFixedPointNumbersExt
#     570.9 ms  ✓ QuadGK
#     618.8 ms  ✓ IntelOpenMP_jll
#     633.3 ms  ✓ HypergeometricFunctions
#     634.4 ms  ✓ Rmath
#     503.8 ms  ✓ Transducers → TransducersAdaptExt
#     589.9 ms  ✓ Adapt → AdaptSparseArraysExt
#     759.3 ms  ✓ Widgets
#     779.1 ms  ✓ Adapt → AdaptStaticArraysExt
#     576.3 ms  ✓ Distances → DistancesSparseArraysExt
#     914.8 ms  ✓ AbstractFFTs → AbstractFFTsTestExt
#     655.8 ms  ✓ AxisAlgorithms
#     504.7 ms  ✓ OffsetArrays → OffsetArraysAdaptExt
#     605.0 ms  ✓ FillArrays → FillArraysPDMatsExt
#     448.3 ms  ✓ Distances → DistancesChainRulesCoreExt
#     456.8 ms  ✓ AbstractFFTs → AbstractFFTsChainRulesCoreExt
#     563.9 ms  ✓ BangBang → BangBangChainRulesCoreExt
#     770.2 ms  ✓ Arpack
#     532.9 ms  ✓ StaticArrays → StaticArraysChainRulesCoreExt
#     702.1 ms  ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#    1122.6 ms  ✓ NearestNeighbors
#     594.5 ms  ✓ MKL_jll
#     893.8 ms  ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#     907.6 ms  ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#    1001.7 ms  ✓ StatsFuns
#     583.6 ms  ✓ StatsFuns → StatsFunsInverseFunctionsExt
#    1297.5 ms  ✓ Clustering
#     914.2 ms  ✓ StatsFuns → StatsFunsChainRulesCoreExt
#    1941.2 ms  ✓ Interpolations
#     691.9 ms  ✓ Interpolations → InterpolationsUnitfulExt
#    2838.4 ms  ✓ Distributions
#    3464.9 ms  ✓ FFTW
#     699.7 ms  ✓ Distributions → DistributionsChainRulesCoreExt
#     734.1 ms  ✓ Distributions → DistributionsTestExt
#    1033.5 ms  ✓ MultivariateStats
#    1419.1 ms  ✓ KernelDensity
#    3338.2 ms  ✓ StatsPlots
#   50 dependencies successfully precompiled in 12 seconds. 310 already precompiled.

# %%
pct_reductions = [0, 20, 40, 60, 80]
regions = ["MA", "CT", "ME"]
cement_types = ["Traditional_Cement_Plant", "EChem_Cement_Plant"]
elec_types = ["Battery", "ThermalPower{NaturalGas}", "Solar", "Wind"]
# Out:
# 4-element Vector{String}:
#  "Battery"
#  "ThermalPower{NaturalGas}"
#  "Solar"
#  "Wind"

# %%
flows_df = CSV.read("results/0pct_co2_reduction_flows.csv", DataFrame)
# Out:
# 446760×10 DataFrame
#     Row │ commodity    commodity_subtype  zone      resource_id        compone ⋯
#         │ String15     String7            String31  String31           String  ⋯
# ────────┼───────────────────────────────────────────────────────────────────────
#       1 │ Electricity  flow               elec_MA   oxyfuel_cement_MA  oxyfuel ⋯
#       2 │ Electricity  flow               elec_MA   oxyfuel_cement_MA  oxyfuel
#       3 │ Electricity  flow               elec_MA   oxyfuel_cement_MA  oxyfuel
#       4 │ Electricity  flow               elec_MA   oxyfuel_cement_MA  oxyfuel
#       5 │ Electricity  flow               elec_MA   oxyfuel_cement_MA  oxyfuel ⋯
#       6 │ Electricity  flow               elec_MA   oxyfuel_cement_MA  oxyfuel
#       7 │ Electricity  flow               elec_MA   oxyfuel_cement_MA  oxyfuel
#       8 │ Electricity  flow               elec_MA   oxyfuel_cement_MA  oxyfuel
#    ⋮    │      ⋮               ⋮             ⋮              ⋮                  ⋱
#  446754 │ Electricity  flow               elec_ME   onshore_wind_ME    onshore ⋯
#  446755 │ Electricity  flow               elec_ME   onshore_wind_ME    onshore
#  446756 │ Electricity  flow               elec_ME   onshore_wind_ME    onshore
#  446757 │ Electricity  flow               elec_ME   onshore_wind_ME    onshore
#  446758 │ Electricity  flow               elec_ME   onshore_wind_ME    onshore ⋯
#  446759 │ Electricity  flow               elec_ME   onshore_wind_ME    onshore
#  446760 │ Electricity  flow               elec_ME   onshore_wind_ME    onshore
#                                                6 columns and 446745 rows omitted

# %%
flows_df.region = [resource_id[end-1:end] for resource_id in flows_df.resource_id]
# Out:
# 446760-element Vector{String31}:
#  "MA"
#  "MA"
#  "MA"
#  "MA"
#  "MA"
#  "MA"
#  "MA"
#  "MA"
#  "MA"
#  "MA"
#  ⋮
#  "ME"
#  "ME"
#  "ME"
#  "ME"
#  "ME"
#  "ME"
#  "ME"
#  "ME"
#  "ME"

# %%
df_commodity = filter(row -> row.commodity == "CO2", flows_df)
df_commodity = filter(row -> row.zone == "co2_sink", df_commodity)
# Out:
# 26280×11 DataFrame
#    Row │ commodity  commodity_subtype  zone      resource_id  component_id     ⋯
#        │ String15   String7            String31  String31     String           ⋯
# ───────┼────────────────────────────────────────────────────────────────────────
#      1 │ CO2        flow               co2_sink  ng_MA        ng_MA_co2_edge   ⋯
#      2 │ CO2        flow               co2_sink  ng_MA        ng_MA_co2_edge
#      3 │ CO2        flow               co2_sink  ng_MA        ng_MA_co2_edge
#      4 │ CO2        flow               co2_sink  ng_MA        ng_MA_co2_edge
#      5 │ CO2        flow               co2_sink  ng_MA        ng_MA_co2_edge   ⋯
#      6 │ CO2        flow               co2_sink  ng_MA        ng_MA_co2_edge
#      7 │ CO2        flow               co2_sink  ng_MA        ng_MA_co2_edge
#      8 │ CO2        flow               co2_sink  ng_MA        ng_MA_co2_edge
#    ⋮   │     ⋮              ⋮             ⋮           ⋮             ⋮          ⋱
#  26274 │ CO2        flow               co2_sink  ng_ME        ng_ME_co2_edge   ⋯
#  26275 │ CO2        flow               co2_sink  ng_ME        ng_ME_co2_edge
#  26276 │ CO2        flow               co2_sink  ng_ME        ng_ME_co2_edge
#  26277 │ CO2        flow               co2_sink  ng_ME        ng_ME_co2_edge
#  26278 │ CO2        flow               co2_sink  ng_ME        ng_ME_co2_edge   ⋯
#  26279 │ CO2        flow               co2_sink  ng_ME        ng_ME_co2_edge
#  26280 │ CO2        flow               co2_sink  ng_ME        ng_ME_co2_edge
#                                                 6 columns and 26265 rows omitted

# %%
df_pivot = unstack(df_commodity, :type, :region, :value, combine=sum)
# Out:
# 1×4 DataFrame
#  Row │ type                      MA         CT         ME
#      │ String31                  Float64?   Float64?   Float64?
# ─────┼──────────────────────────────────────────────────────────
#    1 │ ThermalPower{NaturalGas}  1.27121e7  9.14953e6   397.171

# %%
# Function for getting the capacity of certain technologies, split by region
function get_processed_capacity_df(capacity_df, types)
    # Add region column
    capacity_df.region = [resource_id[end-1:end] for resource_id in capacity_df.resource_id]

    # Rename tech types
    capacity_df.type[1:3] .= "Traditional_Cement_Plant"
    capacity_df.type[4:6] .= "EChem_Cement_Plant"
    capacity_df.type[15:16] .= "Solar"
    capacity_df.type[17:18] .= "Wind"

    # Filter out the types you want
    df_types = filter(row -> row.type in types, capacity_df)

    # Pivot table for readability
    df_pivot = unstack(df_types, :type, :region, :value)
    df_pivot = coalesce.(df_pivot, 0.0)

    return df_pivot
end

# Function for processing the flows of a specific commodity, split by region
function get_processed_flows_df(flows_df, commodity)
    # Add region column
    flows_df.region = [resource_id[end-1:end] for resource_id in flows_df.resource_id]

    # Filter out the types you want
    df_commodity = filter(row -> row.commodity == commodity, flows_df)

    # Pivot table for readability
    df_pivot = unstack(df_commodity, :type, :region, :value, combine=sum)
    df_pivot = coalesce.(df_pivot, 0.0)

    return df_pivot
end

# Function for getting a dictionary of dataframes for each scenario
function get_df_dict(dir, pct_list, metric, tech_types, commodity)
    # tech_types only needed for capacity_results_df (for filtering out which technology capacities you want to plot)
    # commodity only needed for flows_results_df (for summing over total flow of one commodity)
    df_dict = OrderedDict()
    for pct in pct_list
        filepath = "results/" * string(dir) * "/" * string(pct) * "pct_co2_reduction_" * metric * ".csv"
        df = CSV.read(filepath, DataFrame)
        if metric == "capacity"
            df_types = get_processed_capacity_df(df, tech_types)
        elseif metric == "flows"
            df_types = get_processed_flows_df(df, commodity)
        end
        df_dict[pct] = df_types
    end
    return df_dict
end

function get_matrix(df)
    matrix = Matrix(df[:, regions])'
    return matrix
end
# Out:
# get_matrix (generic function with 1 method)

# %%
function plot_df_dict(df_dict, legend_labels, ylabel, ylim)
    n = length(df_dict)

    # 1. Define 3x2 grid layout
    plot_layout = @layout [a b c; d e f]
    
    # 2. Create the big plot with the layout
    p = plot(layout = plot_layout, size = (800, 500))  # Adjust width/height as needed
    
    values = nothing
    # 3. Loop over each scenario
    for (i, (pct, df)) in enumerate(df_dict)
        values = get_matrix(df)

        if legend_labels == nothing
            legend_labels = df.type
        end
    
        # Plot in correct subplot
        groupedbar!(
            regions,
            values,
            bar_position = :stack,
            bar_width = 0.7,
            xlabel = "Regions",
            ylabel = ylabel,
            title = "$(pct)% CO₂ Reduction",
            ylim = ylim,
            subplot = i,
            legend = false # Only show legend in last plot
        )
    end
    
    # 4. Add empty plot in subplot 6 with only legend
    groupedbar!(
        zeros(size(values)),    # Empty y data but correct shape
        label = permutedims(legend_labels), # Labels only for legend
        subplot = 6,
        legend = :left,
        framestyle = :none,              # Remove axes/frames
    )
    
    display(p)

end
# Out:
# plot_df_dict (generic function with 1 method)

# %% [markdown]
# ## Use "False" for no CO2 constraint

# %%
elec_capacity = get_df_dict("", pct_reductions, "capacity", elec_types, "")
plot_df_dict(elec_capacity, elec_types, "Elec Capacity (MW)", (0, 3e4))

# %%
cement_capacity = get_df_dict("", pct_reductions, "capacity", cement_types, "")
plot_df_dict(cement_capacity, cement_types, "Cement Capacity (Tons)", (0, 400))

# %%
commodity = "CO2"
total_flow = get_df_dict("", pct_reductions, "flows", "", commodity)
plot_df_dict(total_flow, nothing, "Total CO2 Flow (tons)", (0, 1.5e7))
